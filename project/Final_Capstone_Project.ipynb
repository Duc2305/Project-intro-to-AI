# %% [markdown]
# # **1. Problem Description and Data Preparation**

# %% [markdown]
# ## **1.1. Problem description:**
#
# Given a grayscale topographic map of a part of Mars and some features of the land rover.
#
# Assume that:
#
# + The land rover knows the starting point and the ending point, it has also an elevation map in which the height is represented by 254 pixels (2 for the deepest position and 255 for the highest position) and the sensors to know where it is. $(1)$
#
# + The land rover can move in only 4 directions: forward, backward, left and right, it can go up or down with an inclination of $\theta \leq 10^{\circ}$ (this value can be computed by the formula: $tan(\theta) = \dfrac{|h_1 - h_2|}{dist(P_1, P_2)}$ which is the ratio between the altitude difference of $P_1$ and $P_2$ and their real distance ($P_1$ and $P_2$ are 2 consecutive positions, therefore ${dist(P_1, P_2)} = const$). $(2)$
#
# We need to find the shortest path (if it exists) for the land rover to travel between 2 points from the starting point A and the ending point B. The goal is the destination point B.

# %% [markdown]
# ## **1.2. Data Preparation:**
#
# **Import the topography map image from the Internet:**

# %%
file_name = "Mars_MGS_MOLA_DEM.jpg" #The name of the file we want to save

# %%
# DON'T RUN THIS CELL IF YOU ALREADY HAVE THE IMAGE
import requests #Module for getting image from the Internet
response = requests.get("http://planetpixelemporium.com/download/download.php?5672/mars_12k_topo.jpg")

with open(file_name, "wb") as file: #Create a file with the name above and save the content of response to it
    file.write(response.content)

# %% [markdown]
# **Import modules:**

# %%
from PIL import Image # work with images
import matplotlib.pyplot as plt # work with graph
import numpy as np # work with arrays
import time # for analysis process
import queue # queue data structure
import pickle # for saving object
import os 
import pygame
# Out:
# pygame 2.1.1 (SDL 2.0.18, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# This is Mars Orbiter Laser Altimeter **(MOLA)** map of Mars. According to NASA, "MOLA is an instrument on the Mars Global Surveyor (MGS), a spacecraft that was launched on November 7, 1996. The mission of MGS was to orbit Mars, and map it over the course of approximately 3 years, which it did sucessfully, completing 4 1/2 years of mapping."

# %%
img = Image.open(file_name) #Open our saved file above

# %% [markdown]
# **Image description:**
#
# As we can see in the image, the darker region means that the region is deeper, the lighter areas mean higher altitude.

# %%
print("Shape of original image: ", np.asarray(img).shape)
img = img.convert("L") #Convert to one channel grey image
img_array = np.asarray(img)  #Convert the image to an array
img_array = img_array.astype('int32')
print("Shape of converted image: ", img_array.shape)
print("Image_array[0:2]: ", *img_array[0:2]) 
print()
# Out:
# Shape of original image:  (6144, 12288)
# Shape of converted image:  (6144, 12288)
# Image_array[0:2]:  [56 56 56 ... 56 56 56] [56 56 56 ... 56 56 56]

# %%
plt.figure(figsize = (16,9), dpi = 120) #Figure setting for plotting
plt.axis('off') #Turn off axis
plt.imshow(img_array, cmap = 'gray') #Show the gray figure
plt.title("MOLA Mars map 12K")
plt.show()

# %% [markdown]
# **Mars information:**
#
# According to NASA, the maximum altitude is 21229 m (peak of Olympus Mons) and the minimum altitude is -8200m (Hellas Impact Crater).
#
# The pixel resolution of this map is 1736.25 meters per pixel (m). So $dist(P_1,P_2) = const = 1736.25 (m)$ ($P_1$ and $P_2$ are 2 consecutive positions).

# %% [markdown]
# **Topography map information:**
#
# According to https://homepages.inf.ed.ac.uk/rbf/HIPR2/value.htm, we need to note that for a grayscale image, the pixel value is a single number that represents the brightness of the pixel. The most common pixel format is the byte image, where this number is stored as an 8-bit integer giving a range of possible values from 0 to 255. Typically zero is taken to be black, and 255 is taken to be white.
#
# For this particular MOLA Mars map image above, we found that the maximum height (which is equivalent to the peak of Olympus Mons) is represented by a pixel value of 255 and the minimum height (which is equivalent to the Hellas Impact Crater) is represented by a pixel value of 2 (this is the reason why in part $(1)$ of the problem description, we assume that 2 is the pixel value representing for the deepest position and 255 for the highest position)
#
# Therefore, each value pixel represents for: $\dfrac{1}{255 - 2 + 1} \times (max_{height} - min_{height}) = \dfrac{1}{254} \times (21229 + 8200) = 115.86$ meters of height.

# %% [markdown]
# **Random picking:**
# + The starting point
# + The destination

# %%
start = (np.random.randint(12288), np.random.randint(6144))
end = (np.random.randint(12288), np.random.randint(6144))
print("Starting point: ", start, "Ending point: ", end)
print()
plt.figure(figsize = (16,9), dpi = 120) #Figure setting for plotting
plt.imshow(img_array, cmap = 'gray') #Show the gray figure
plt.scatter(*start) #Plot the starting point
plt.scatter(*end) #Plot the ending point
plt.title("MOLA Mars map")
plt.legend(["Starting point", "Ending point"])
plt.show()
# Out:
# Starting point:  (3310, 4752) Ending point:  (1259, 26)

# %% [markdown]
# We need to find the shortest path (if it exists) for the land rover to travel between 2 points from the starting point A and the ending point B, but our path needs to satisfy $(2)$. Let's take an example of 2 consecutive points that our land rover can't move between them.
#
# Take 2 points $P_1$ and $P_2$ next to each other:
#
# + P1: img_array[2000,5085] = 75
# + P2: img_array[2000,5086] = 78
#
# Since the difference between the pixel value of these 2 points is 3, so in reality, the difference between the elevation of these 2 points is $3 \times 115.86 = 347.58 (m)$. Others, because $dist(P_1,P_2) = const = 1736.25 (m)$. Therefore $\theta = arctan\left(\dfrac{347.58}{1736.25}\right) = 11.32 ^{\circ} > 10 ^{\circ}$. In conclusion, the land rover can't go from $P_1$ to $P_2$ or vice versa.

# %% [markdown]
# # 2. Analysis Plan
#
# In order to solve this problem, we consider:
#
# + 3 algorithms (1 uninformed search algorithms and 2 informed search algorithms): Uniform cost search, A* search, Greedy best first search.
#
# + 2 data structures with different sort algorithms for frontier: Priority queue (with heap sort) and List (with timsort)
#
# + 2 approaches for finding the neighbors of each point: Create the list of neighborhood for each node first and put it in an array before running the algorithm; Check the available neighbors for each node while running the algorithm.
#
# + 5 types of heuristics: using Manhattan distance; Euclidean distance; Octile distance; Tie-Breaking Low g-cost; Tie-Breaking High g-cost.
#
# Others, since the original image has a very big size $(6144 \times 12288)$, therefore we consider only the part of this image with different size $15 \times 15, 20 \times 20, 25 \times 25, 30 \times 30)$.
#
# We hypothesize also that the running time of each algorithm depends also on the standard deviation of pixel value for each value, therefore we need to divide the original image into many small images belonging to each bin of standard deviation!

# %%
# img_size = [15, 20, 25, 30, 50, 75, 100] # All the image size that we consider

# Just for visualization of this Jupyter Notebook, the running time of 
# the next cells below are too slow if we take all the size of the images
img_size = [25,50]

# %% [markdown]
# # 3. Data Preparation

# %%
x_max, y_max = img_array.shape
print("x_max: {}, y_max: {}".format(x_max, y_max))
# Out:
# x_max: 6144, y_max: 12288

# %%
# %%time 

# Arrays[size] stores the data of images having specific size
arrays = {}

# We show only the case where img_size = 15, for the remaining cases, we do 
# the same analysis as below and we got the similar results
size = img_size[1] 

# Create a list for storing a tuple of image and its standard deviation (section, np.std(section))
arrays[size] = []

# Generate data
for i in range(0, x_max - size + 1, size//5): # Step = size//5
    for j in range(0, y_max - size + 1, size//5): # Step = size//5
        section = img_array[i:i + size, j:j + size] # Take the section of image
        arrays[size].append((section, np.std(section))) # Append (section, standard_deviation(section)) to arrays[size]

#Sort the image sections according to the standard deviation
arrays[size] = sorted(arrays[size], key = lambda tup: tup[1])
# Out:
# Wall time: 17.4 s

# %%
# %%time
# Store all the standard deviations to std_data
std_data = np.array([x[1] for x in arrays[size]])

# Plot all the data in std_data
plt.figure(figsize = (16, 9), dpi = 80)
plt.hist(std_data, bins = 100)
plt.show()
# Out:
# Wall time: 634 ms

# %% [markdown]
# For images of size $15$, we can see that the standard deviation of each small images is near by 0. Let's consider only the case where the standard deviation of an image is less than $8$.

# %%
# %%time
# Crop the std_data and save it to std_data_crop, we just consider the case where the standard deviation which is less than 8
std_data_crop = np.array([x for x in std_data if x < 8])

# Plot all the data in std_data
plt.figure(figsize = (16, 9), dpi = 80)
plt.hist(std_data_crop, bins = 18)
plt.show()
# Out:
# Wall time: 283 ms

# %% [markdown]
# From the histogram above, we can see that, most standard deviations are between $0$ and $1$. In order to discover the effect of standard deviations on the algorithm running time, we take the data in the first $16$ bins (each bin has size $0.5$).

# %% [markdown]
# # 4. Analysis
#
# 3 algorithms (1 uninformed search algorithms and 2 informed search algorithms): Uniform cost search, A* search, Greedy best first search.
#
# 2 data structures with different sort algorithms for frontier: Priority queue (with heap sort) and List (with timsort)
#
# 2 approaches for finding the neighbors of each point: Create the list of neighborhood for each node first and put it in an array before running the algorithm; Check the available neighbors for each node while running the algorithm.
#
# 5 types of heuristics: using Manhattan distance; Tie-Breaking High g-cost, Variance of Tie-Breaking High g-cost, Tie-Breaking Low g-cost, Variance of Tie-Breaking Low g-cost.
#
# # 4.1. Preparation

# %% [markdown]
# Get the data
# + For $img_{size} = 15$, we consider only the case where the standard deviation of an image is less than $8$ and we choose also the first 16 bins of size 0.5.
#
# + For $img_{size} = 20$, we consider only the case where the standard deviation of an image is less than $8$ and we choose also the first 16 bins of size 0.5.
#
# + For $img_{size} = 25$, we consider only the case where the standard deviation of an image is less than $8$ and we choose also the first 16 bins of size 0.5.
#
# + For $img_{size} = 30$, we consider only the case where the standard deviation of an image is less than $8$ and we choose also the first 16 bins of size 0.5.
#
# + For $img_{size} = 50$, we consider only the case where the standard deviation of an image is less than $8$ and we choose also the first 16 bins of size 0.5.
#
# + For $img_{size} = 75$, we consider only the case where the standard deviation of an image is less than $8$ and we choose also the first 16 bins of size 0.5.
#
# + For $img_{size} = 100$, we consider only the case where the standard deviation of an image is less than $8$ and we choose also the first 16 bins of size 0.5.

# %%
# %%time
import random 

#Variables
arrays = {}
data = {}

#Bin information
num_bins = 16
bin_size = 0.5

for size in img_size:
    arrays[size] = []
    for i in range(0, x_max - size + 1, size//5):
        for j in range(0, y_max - size + 1, size//5):
            section = img_array[i:i + size, j:j + size]
            arrays[size].append((section, np.std(section)))

for size in img_size:
    tmp_data = {}
    
    i = bin_size
    
    while i <= num_bins * bin_size:
        
        #Standard deviation filtering
        tmp_data[(i-bin_size,i)] = [arr[0] for arr in arrays[size] if arr[1] < i] 
        
        #Randomize our data before writing it to a txt file
        random.shuffle(tmp_data[(i-bin_size,i)]) 
        
        #Save only 100 random images for analysis process
        tmp_data[(i-bin_size,i)] = tmp_data[(i-bin_size,i)][0:1] # Take only 1 image for fast video capture  
        
        i += bin_size
    
    data[size] = tmp_data
# Out:
# Wall time: 1min 56s

# %% [markdown]
# Path for storing our analysis results

# %%
path = "Analysis Results"

# Make folder if path does not exist
if os.path.exists(path) == False:
    os.mkdir(path)

# %% [markdown]
# Heuristic functions

# %%
# Manhattan distance
def manhattan(actual_node, start_node ,goal_node, delta):
    actualPos = actual_node.position
    endPos = goal_node.position
    return abs(actualPos[0] - endPos[0]) + abs(actualPos[1] - endPos[1])

# There are many states with the same f-cost, and we have to choose the order in which to expand them. 
# For tie_breaking_high_g_cost, we preferred states closer to the goal node than the goal state.
def tie_breaking_high_g_cost(actual_node, start_node, goal_node, delta = 0.001):
    actualPos = actual_node.position
    endPos = goal_node.position
    return manhattan(actual_node, start_node, goal_node) * (1 + delta)

# Variance of tie breaking high g-cost, we vary the value of delta in tie_breaking_high_g_cost, according
# to the position of the actual node
def var_tie_breaking_high_g_cost(actual_node, start_node, goal_node, delta = 0.001):
    actualPos = actual_node.position
    endPos = goal_node.position
    rate1 = manhattan(actual_node, start_node, goal_node)
    rate2 = manhattan(start_node, start_node, goal_node)
    return rate1 * (1 + delta* (0.5 + rate1/rate2))

# There are many states with the same f-cost, and we have to choose the order in which to expand them. 
# For tie_breaking_low_g_cost, we preferred states closer to the start node than the goal state.
def tie_breaking_low_g_cost(actual_node, start_node, goal_node, delta = 0.001):
    actualPos = actual_node.position
    endPos = goal_node.position
    return manhattan(actual_node, start_node, goal_node) * (1 - delta)

# Variance of tie breaking low g-cost, we vary the value of delta in tie_breaking_low_g_cost, according
# to the position of the actual node
def var_tie_breaking_low_g_cost(actual_node, start_node, goal_node, delta = 0.001):
    actualPos = actual_node.position
    endPos = goal_node.position
    rate1 = manhattan(actual_node, start_node, goal_node)
    rate2 = manhattan(start_node, start_node, goal_node)
    return rate1 * (1 + delta * (1.5 - rate1/rate2))

# Heuristics dictionary containing all kinds of heuristic functions
heuristics = {
    'manhattan': manhattan,
    'tie_breaking_high_g_cost': tie_breaking_high_g_cost,
    'var_tie_breaking_high_g_cost': var_tie_breaking_high_g_cost,
    'tie_breaking_low_g_cost': tie_breaking_low_g_cost,
    'var_tie_breaking_low_g_cost': var_tie_breaking_low_g_cost
}

# %% [markdown]
# Node definition, Analysis object, Methods of finding neighbors, Data initialization

# %%
#------------------------------------------ Node definition -----------------------------------------
class Node():
    # Node initialization
    def __init__(self, position):
        self.position = position # Tuple (x,y)
        self.g = 0 # g-cost
        self.h = 0 # h-cost
        self.f = None # f-cost
        self.parent = None # Parent node
    
    # Print the node
    def __str__(self): 
        return str(self.position)
    
    # Equality of 2 nodes (position)
    def __eq__(self, other):
        return self.position == other.position
    
    # Less than
    def __lt__(self, other):
        return self.f < other.f
    
    # Greater than
    def __gt__(self, other):
        return self.f > other.f


#-------------------------------------- Analysis initialization -------------------------------------
# Define the class containing our analysis results
class AnalysisResults:
    def __init__(self, size):
        self.size = size # Size of image
        
        # Dictionary of average run time and average steps_count, for example: 
        # avg_run_time[(0,0.5)] returns the average run time of image inside the 
        # bin of standard deviation from 0 to 0.5
        self.avg_run_time = {}
        self.avg_steps_count = {}
        
        
#----------------------------------------- Finding neighbors ----------------------------------------
# Finding while runing
def next_pos_list(array, actual_node, img_shape, theta):
    '''
    array: array of height value
    actual_node: node object of the actual node that you want to find its neighbors
    img_shape: tuple(x_size, y_size) - size of the image
    theta: maximum distance of heigh between 2 consecutive positions
    '''
    res = []
    x_size, y_size = img_shape
    actualPos = actual_node.position
    actual_nodeValue = array[actualPos[0]][actualPos[1]]
    
    # Conditions checking for neighbors
    if actualPos[0] + 1 < x_size and abs(actual_nodeValue - array[actualPos[0] + 1][actualPos[1]]) <= theta:
        res.append((actualPos[0] + 1, actualPos[1]))
    if actualPos[1] + 1 < y_size and abs(actual_nodeValue - array[actualPos[0]][actualPos[1] + 1]) <= theta:
        res.append((actualPos[0], actualPos[1] + 1))
    if actualPos[0] - 1 >= 0 and abs(actual_nodeValue - array[actualPos[0] - 1][actualPos[1]]) <= theta:
        res.append((actualPos[0] - 1, actualPos[1]))
    if actualPos[1] - 1 >= 0 and abs(actual_nodeValue - array[actualPos[0]][actualPos[1] - 1]) <= theta:
        res.append((actualPos[0], actualPos[1] - 1))
    
    return res
       
    
# Find neighbors first before run
def make_grid(array, img_shape, theta):
    '''
    array: array of height value
    img_shape: tuple(x_size, y_size) - size of the image
    theta: maximum distance of heigh between 2 consecutive positions
    '''
    grid = [[None for j in range(len(array))] for i in range(len(array))]
    x_size, y_size = img_shape

    for i in range(len(array)):
        for j in range(len(array)):
            res = []
            actual_nodeValue = int(array[i][j])  
            
            # Conditions checking for neighbors
            if i + 1 < x_size and abs(actual_nodeValue - int(array[i + 1][j])) <= theta:
                res.append((i + 1,j))
            if j + 1 < y_size and abs(actual_nodeValue - int(array[i][j + 1])) <= theta:
                res.append((i,j + 1))
            if i - 1 >= 0 and abs(actual_nodeValue - int(array[i - 1][j])) <= theta:
                res.append((i - 1,j))
            if j - 1 >= 0 and abs(actual_nodeValue - int(array[i][j - 1])) <= theta:
                res.append((i,j - 1))
            grid[i][j] = res # grid[i][j] contains a list of points which can be the neighbors of the point at position (i,j)
    
    return grid

#----------------------------------------- Data initialization ----------------------------------------
# Random the position of node
def init(size):
    start_node = (np.random.randint(0,size), np.random.randint(0,size))
    goal_node = (np.random.randint(0,size), np.random.randint(0,size))
    return start_node, goal_node

# Create a list of n pairs of nodes
def random_initialization(n, size):
    return [init(size) for i in range(n)]

# %% [markdown]
# ### 4.1.1. Astar analysis function

# %%
def Astar_analysis(data, parameters):        
    #-------------------------------------- 3 different A* algorithms --------------------------------------
    
    # Using list (with timsort) for frontier, finding neighbors while running
    def norm_Astar_list(img_array, start_node, goal_node, img_shape, theta, heuristic):
        
        steps_count = 0 # Save our number of steps
        visited_nodes = set() # Save our visited nodes
        frontier = [start_node] # Add the start_node to the frontier

        while len(frontier) > 0: # While there is something inside the frontier, continue the algorithm
            
            # Sort the frontier in reverse order, here Python uses timsort
            frontier = sorted(frontier, reverse = True)
            
            # Pop the last node, which has the lowest value of f
            actual_node = frontier.pop()
            
            # Add 1 to steps_count for each time we enter a node
            steps_count += 1 
            
            # Save the temporary g-score of the actual node
            tmp_g_score = actual_node.g
            
            # Return the steps_count for analysis process
            if actual_node == goal_node:
                return steps_count
            
            # Add the position (tuple(x,y)) to visited_node
            visited_nodes.add(actual_node.position)
            
            # Create a list of temporary visited nodes, add these nodes to the frontier after the for loop below 
            tmp_visited_nodes = []
            
            # Iterate over all neighbors of the actual node
            for next_pos in next_pos_list(img_array, actual_node, img_shape, theta):
                steps_count += 1 # Add 1 for each time we check the next node
                next_node = Node(next_pos) # Create next_node with position next_pos
                
                # If next_pos in visited_nodes, we don't do anything
                if next_pos not in visited_nodes:

                    #f = h + g, update f-score
                    next_node.g = tmp_g_score + 1
                    next_node.h = heuristic(next_node, start_node, goal_node, delta) 
                    next_node.f = next_node.h + next_node.g
                    next_node.parent = actual_node
                    
                    # If next_node in frontier
                    if next_node in frontier:
                        idx = frontier.index(next_node) # Find the index of next_node in the frontier
                        
                        # If the f-score of the duplicate node is more than that of the actual next_node
                        if frontier[idx] > next_node: 
                            frontier.remove(next_node) # Remove this next_node in the frontier
                            tmp_visited_nodes.append(next_node) # And append the actual next_node to the frontier
                    else:
                        tmp_visited_nodes.append(next_node) # Append the actual next_node to the frontier
            
            # Add all the nodes inside tmp_visited_nodes into frontier
            frontier += tmp_visited_nodes
        
        # Return the number of steps counted for analysis process
        return steps_count
    
    
    # Using priority queue (with heapsort) for frontier, finding neighbors while running
    def norm_Astar_priority_queue(img_array, start_node, goal_node, img_shape, theta, heuristic):
        steps_count = 0 # Save our number of steps
        visited_nodes = set() # Save our visited nodes
        frontier = queue.PriorityQueue()
        frontier.put((0, start_node))

        while frontier.empty() == False:
            actual_node = frontier.get()[1]        
            steps_count += 1 # Add 1 for each time we enter a node
            tmp_g_score = actual_node.g

            if actual_node == goal_node:
                return steps_count

            visited_nodes.add(actual_node.position)

            # Iterate over all neighbors of the actual node
            for next_pos in next_pos_list(img_array, actual_node, img_shape, theta):
                steps_count += 1 # Add 1 for each time we check the next node
                next_node = Node(next_pos) # Create next_node with position next_pos
                
                # If next_pos in visited_nodes, we don't do anything
                if next_pos not in visited_nodes:

                    # f = h + g
                    next_node.g = tmp_g_score + 1
                    next_node.h = heuristic(next_node, start_node, goal_node, delta) 
                    next_node.f = next_node.h + next_node.g
                    next_node.parent = actual_node

                    # Check if there exists a node having the same position as next_node (denoted as duplicate node) 
                    # in the frontier or not
                    if (next_node.f, next_node) in frontier.queue:
                        # Find the index of the duplicate node in the frontier.queue
                        idx = frontier.queue.index((next_node.f, next_node)) 

                        # Check the f-value of the 2 nodes (next_node and the duplicate node in the frontier)
                        if frontier.queue[idx][0] > next_node.f:
                            
                            # Replace the duplicate node by the next_node with lower f-score
                            # Step 1: Create a temporary queue
                            tmp_queue = queue.PriorityQueue()
                            
                            # Step 2: Put all the elements of the frontier to tmp_queue until we find the duplicate node
                            while t != frontier.queue[idx]:
                                t = frontier.get()
                                tmp_queue.put(t)
                            
                            # Step 3: Delete the duplicate node
                            t = frontier.get()
                            
                            # Step 4: Reput all the elements from the tmp_queue to the frontier
                            while tmp.empty() == False:
                                t = tmp_queue.get()
                                frontier.put(t)    
                                
                            frontier.put((next_node.f, next_node)) # Put next_node to frontier
                    else:
                        frontier.put((next_node.f, next_node)) # Put next_node to frontier
        
        # Return the number of steps counted for analysis process
        return steps_count
    
    
     # Using list (with timsort) for frontier, finding neighbors before running
    def Astar_list_with_init(grid, img_array, start_node, goal_node, img_shape, theta, heuristic):    
        steps_count = 0 # Save our number of steps
        visited_nodes = set() # Save our visited nodes
        frontier = [start_node] # Add the start_node to the frontier

        while len(frontier) > 0: # While there is something inside the frontier, continue the algorithm
            
            # Sort the frontier in reverse order, here Python uses timsort
            frontier = sorted(frontier, reverse = True)
            
            # Pop the last node, which has the lowest value of f
            actual_node = frontier.pop()
            
            # Add 1 to steps_count for each time we enter a node
            steps_count += 1 
            
            # Save the temporary g-score of the actual node
            tmp_g_score = actual_node.g
            
            # Return the steps_count for analysis process
            if actual_node == goal_node:
                return steps_count
            
            # Add the position (tuple(x,y)) to visited_node
            visited_nodes.add(actual_node.position)
            
            # Create a list of temporary visited nodes, add these nodes to the frontier after the for loop below 
            tmp_visited_nodes = []

            # Iterate over all neighbors of the actual node
            for next_pos in grid[actual_node.position[0]][actual_node.position[1]]:
                steps_count += 1 # Add 1 for each time we check the next node
                next_node = Node(next_pos) # Create next_node with position next_pos
                
                # If next_pos in visited_nodes, we don't do anything
                if next_pos not in visited_nodes:

                    #f = h + g, update f-score
                    next_node.g = tmp_g_score + 1
                    next_node.h = heuristic(next_node, start_node, goal_node, delta) 
                    next_node.f = next_node.h + next_node.g
                    next_node.parent = actual_node

                    # If next_node in frontier
                    if next_node in frontier:
                        idx = frontier.index(next_node) # Find the index of next_node in the frontier
                        
                        # If the f-score of the duplicate node is more than that of the actual next_node
                        if frontier[idx] > next_node: 
                            frontier.remove(next_node) # Remove this next_node in the frontier
                            tmp_visited_nodes.append(next_node) # And append the actual next_node to the frontier
                    else:
                        tmp_visited_nodes.append(next_node) # Append the actual next_node to the frontier
            
            # Add all the nodes inside tmp_visited_nodes into frontier
            frontier += tmp_visited_nodes
        
        # Return the number of steps counted for analysis process
        return steps_count    
    
    #------------------------------------ Retrieving data from parameters ------------------------------------
    
    #List of image size:
    img_size = parameters['img_size']
    
    #Type of frontier (list or priority_queue)
    frontier_type = parameters['frontier_type']    
    
    #Type of finding neighbors (find_first_before_run or find_while_running)
    finding_neighbors = parameters['finding_neighbors']
    
    #Choose Astar version
    if finding_neighbors == 'find_while_running' and frontier_type == 'list':
        Astar = norm_Astar_list 
    elif finding_neighbors == 'find_while_running' and frontier_type == 'priority_queue':
        Astar = norm_Astar_priority_queue
    elif finding_neighbors == 'find_first_before_run' and frontier_type == 'list':
        Astar = Astar_list_with_init
    
    #Type of heuristic function (manhattan; tie_breaking_high_g_cost)
    global heuristics
    heuristic_type = parameters['heuristic_type'] 
    heuristic = heuristics[heuristic_type]
    
    #Delta for heuristic functions
    delta = 0.001
    if 'delta' in parameters.keys():
        delta = parameters['delta']

    #Number of random starting points and ending points to run analysis
    num_points = parameters['num_points'] 
    
    
    #-------------------------------------------- Analysis process --------------------------------------------
    # Store the analysis results
    analysis_results = []
    
    # Iterate over all the image size in data.keys()
    for size in data.keys():
        
        # Preparation
        analysis_results.append(AnalysisResults(size)) # Create a new AnalysisResults object and append it to the list
        pair_node_list = random_initialization(num_points, size) # Create a random pair of start node and goal node
        print("Image size: {}".format(size))

        # Run the analysis for loop
        for data_bin_key in data[size].keys():
                
            i = 1
            total_time = 0
            total_steps_count = 0
            num_images = len(data[size][data_bin_key])

            for start_node, goal_node in pair_node_list:
                
                # Create start_node and goal_node objects
                start_node = Node(start_node)
                goal_node = Node(goal_node)

                # Iterate over all image in data[size][data_bin_key], for example if we want to access to the list of
                # images of size 15 inside the data_bin (0,0.5) -> data[15][(0,0.5)]
                for tmp_data in data[size][data_bin_key]:
                    
                    # Different type of analysis for each finding_neighbors algorithm
                    if finding_neighbors ==  'find_first_before_run':
                        grid = make_grid(tmp_data, (size, size), 2) # Make grid of neighbors first before run the algorithm
                        start_time = time.time() 
                        steps_count = Astar(grid, tmp_data, start_node, goal_node, (size, size), 2, heuristic)
                        running_time = time.time() - start_time # Running time 
                    else:
                        start_time = time.time()
                        steps_count = Astar(tmp_data, start_node, goal_node, (size, size), 2, heuristic)
                        running_time = time.time() - start_time # Running time             
                    
                    total_time += running_time
                    total_steps_count += steps_count
                    
            print("Standard deviation range: {}".format(data_bin_key))
            
            # Average running time
            tmp_avg_run_time = total_time / num_images / num_points
            analysis_results[-1].avg_run_time[data_bin_key] = tmp_avg_run_time
            print("Average running time: {} s.".format(tmp_avg_run_time))

            # Average steps count
            tmp_avg_steps_count = total_steps_count // num_images // num_points
            analysis_results[-1].avg_steps_count[data_bin_key] = tmp_avg_steps_count
            print("Average steps counts: {} steps.".format(tmp_avg_steps_count))
                                         
        print("------------------------------------")
                                         
    return analysis_results

# %% [markdown]
# ### 4.1.2. Greedy BFS analysis function

# %%
def GreedyBFS_analysis(data, parameters):        
    #-------------------------------------- 4 different A* algorithms --------------------------------------
    
    def norm_GreedyBFS_list(img_array, start_node, goal_node, img_shape, theta, heuristic):
        steps_count = 0 # Save our number of steps
        visited_nodes = set() # Save our visited nodes
        frontier = [start_node] # Add the start_node to the frontier

        while len(frontier) > 0: # While there is something inside the frontier, continue the algorithm
            
            # Sort the frontier in reverse order, here Python uses timsort
            frontier = sorted(frontier, reverse = True)
            
            # Pop the last node, which has the lowest value of f
            actual_node = frontier.pop()
            
            # Add 1 to steps_count for each time we enter a node
            steps_count += 1 
            
            # Save the temporary g-score of the actual node
            tmp_g_score = actual_node.g
            
            # Return the steps_count for analysis process
            if actual_node == goal_node:
                return steps_count
            
            # Add the position (tuple(x,y)) to visited_node
            visited_nodes.add(actual_node.position)
            
            # Create a list of temporary visited nodes, add these nodes to the frontier after the for loop below 
            tmp_visited_nodes = []

            # Iterate over all neighbors of the actual node
            for next_pos in next_pos_list(img_array, actual_node, img_shape, theta):
                steps_count += 1 # Add 1 for each time we check the next node
                next_node = Node(next_pos) # Create next_node with position next_pos
                
                # If next_pos in visited_nodes, we don't do anything
                if next_pos not in visited_nodes:

                    #f = h + g, update f-score
                    next_node.h = heuristic(next_node, start_node, goal_node, delta) 
                    next_node.f = next_node.h
                    next_node.parent = actual_node

                    # If next_node in frontier
                    if next_node in frontier:
                        idx = frontier.index(next_node) # Find the index of next_node in the frontier
                        
                        # If the f-score of the duplicate node is more than that of the actual next_node
                        if frontier[idx] > next_node: 
                            frontier.remove(next_node) # Remove this next_node in the frontier
                            tmp_visited_nodes.append(next_node) # And append the actual next_node to the frontier
                    else:
                        tmp_visited_nodes.append(next_node) # Append the actual next_node to the frontier
            
            # Add all the nodes inside tmp_visited_nodes into frontier
            frontier += tmp_visited_nodes
        
        # Return the number of steps counted for analysis process
        return steps_count
    
    
    def norm_GreedyBFS_priority_queue(img_array, start_node, goal_node, img_shape, theta, heuristic):
        steps_count = 0 #Save our number of steps
        visited_nodes = set() # Save our visited nodes
        frontier = queue.PriorityQueue()
        frontier.put((0, start_node))

        while frontier.empty() == False:
            actual_node = frontier.get()[1]        
            steps_count += 1 # Add 1 for each time we enter a node
            
            # Save the temporary g-score of the actual node
            tmp_g_score = actual_node.g

            if actual_node == goal_node:
                return steps_count

            visited_nodes.add(actual_node.position)

            # Iterate over all neighbors of the actual node
            for next_pos in next_pos_list(img_array, actual_node, img_shape, theta):
                steps_count += 1 # Add 1 for each time we check the next node
                next_node = Node(next_pos) # Create next_node with position next_pos
                
                # If next_pos in visited_nodes, we don't do anything
                if next_pos not in visited_nodes:

                     #f = h + g
                    next_node.h = heuristic(next_node, start_node, goal_node, delta) 
                    next_node.f = next_node.h
                    next_node.parent = actual_node

                    # Check if there exists a node having the same position as next_node (denoted as duplicate node) 
                    # in the frontier or not
                    if (next_node.f, next_node) in frontier.queue:
                        # Find the index of the duplicate node in the frontier.queue
                        idx = frontier.queue.index((next_node.f, next_node)) 

                        # Check the f-value of the 2 nodes (next_node and the duplicate node in the frontier)
                        if frontier.queue[idx][0] > next_node.f:
                            
                            # Replace the duplicate node by the next_node with lower f-score
                            # Step 1: Create a temporary queue
                            tmp_queue = queue.PriorityQueue()
                            
                            # Step 2: Put all the elements of the frontier to tmp_queue until we find the duplicate node
                            while t != frontier.queue[idx]:
                                t = frontier.get()
                                tmp_queue.put(t)
                            
                            # Step 3: Delete the duplicate node
                            t = frontier.get()
                            
                            # Step 4: Reput all the elements from the tmp_queue to the frontier
                            while tmp.empty() == False:
                                t = tmp_queue.get()
                                frontier.put(t)    
                                
                            frontier.put((next_node.f, next_node)) # Put next_node to frontier
                    else:
                        frontier.put((next_node.f, next_node)) # Put next_node to frontier
        
        # Return the number of steps counted for analysis process
        return steps_count
    
    
    def GreedyBFS_list_with_init(grid, img_array, start_node, goal_node, img_shape, theta, heuristic):    
        steps_count = 0 #Save our number of steps
        visited_nodes = set() # Save our visited nodes
        frontier = [start_node] # Add the start_node to the frontier

        while len(frontier) > 0: # While there is something inside the frontier, continue the algorithm
            
            # Sort the frontier in reverse order, here Python uses timsort
            frontier = sorted(frontier, reverse = True)
            
            # Pop the last node, which has the lowest value of f
            actual_node = frontier.pop()
            
            # Add 1 to steps_count for each time we enter a node
            steps_count += 1 
            
            # Save the temporary g-score of the actual node
            tmp_g_score = actual_node.g
            
            # Return the steps_count for analysis process
            if actual_node == goal_node:
                return steps_count
            
            # Add the position (tuple(x,y)) to visited_node
            visited_nodes.add(actual_node.position)
            
            # Create a list of temporary visited nodes, add these nodes to the frontier after the for loop below 
            tmp_visited_nodes = []

            # Iterate over all neighbors of the actual node
            for next_pos in grid[actual_node.position[0]][actual_node.position[1]]:
                steps_count += 1 # Add 1 for each time we check the next node
                next_node = Node(next_pos) # Create next_node with position next_pos
                
                # If next_pos in visited_nodes, we don't do anything
                if next_pos not in visited_nodes:

                    #f = h + g, update f-score
                    next_node.h = heuristic(next_node, start_node, goal_node, delta) 
                    next_node.f = next_node.h
                    next_node.parent = actual_node

                    # If next_node in frontier
                    if next_node in frontier:
                        idx = frontier.index(next_node) # Find the index of next_node in the frontier
                        
                        # If the f-score of the duplicate node is more than that of the actual next_node
                        if frontier[idx] > next_node: 
                            frontier.remove(next_node) # Remove this next_node in the frontier
                            tmp_visited_nodes.append(next_node) # And append the actual next_node to the frontier
                    else:
                        tmp_visited_nodes.append(next_node) # Append the actual next_node to the frontier
            
            # Add all the nodes inside tmp_visited_nodes into frontier
            frontier += tmp_visited_nodes
        
        # Return the number of steps counted for analysis process
        return steps_count
    
    
    #------------------------------------ Retrieving data from parameters ------------------------------------
    
    #List of image size:
    img_size = parameters['img_size']
    
    #Type of frontier (list or priority_queue)
    frontier_type = parameters['frontier_type']    
    
    #Type of finding neighbors (find_first_before_run or find_while_running   finding_neighbors = parameters['finding_neighbors']
    finding_neighbors = parameters['finding_neighbors']
    
    #Choose GreedyBFS version
    if finding_neighbors == 'find_while_running' and frontier_type == 'list':
        GreedyBFS = norm_GreedyBFS_list 
    elif finding_neighbors == 'find_while_running' and frontier_type == 'priority_queue':
        GreedyBFS = norm_GreedyBFS_priority_queue
    elif finding_neighbors == 'find_first_before_run' and frontier_type == 'list':
        GreedyBFS = GreedyBFS_list_with_init
    
    #Type of heuristic function (manhattan; tie_breaking_high_g_cost)
    global heuristics
    heuristic_type = parameters['heuristic_type'] 
    heuristic = heuristics[heuristic_type]
    
    #Delta for heuristic functions
    delta = 0.001
    if 'delta' in parameters.keys():
        delta = parameters['delta']

    #Number of random starting points and ending points to run analysis
    num_points = parameters['num_points'] 
    
    #-------------------------------------------- Analysis process --------------------------------------------
    # Store the analysis results
    analysis_results = []
    
    # Iterate over all the image size in data.keys()
    for size in data.keys():
        
        # Preparation
        analysis_results.append(AnalysisResults(size)) # Create a new AnalysisResults object and append it to the list
        pair_node_list = random_initialization(num_points, size) # Create a random pair of start node and goal node
        print("Image size: {}".format(size))

        # Run the analysis for loop
        for data_bin_key in data[size].keys():
                
            i = 1
            total_time = 0
            total_steps_count = 0
            num_images = len(data[size][data_bin_key])

            for start_node, goal_node in pair_node_list:
                
                # Create start_node and goal_node objects
                start_node = Node(start_node)
                goal_node = Node(goal_node)

                # Iterate over all image in data[size][data_bin_key], for example if we want to access to the list of
                # images of size 15 inside the data_bin (0,0.5) -> data[15][(0,0.5)]
                for tmp_data in data[size][data_bin_key]:
                    
                    # Different type of analysis for each finding_neighbors algorithm
                    if finding_neighbors ==  'find_first_before_run': 
                        grid = make_grid(tmp_data, (size, size), 2) # Make grid of neighbors first before run the algorithm
                        start_time = time.time()
                        steps_count = GreedyBFS(grid, tmp_data, start_node, goal_node, (size, size), 2, heuristic)
                        running_time = time.time() - start_time # Running time
                    else:
                        start_time = time.time()
                        steps_count = GreedyBFS(tmp_data, start_node, goal_node, (size, size), 2, heuristic)
                        running_time = time.time() - start_time # Running time  
                    
                    total_time += running_time
                    total_steps_count += steps_count

            print("Standard deviation range: {}".format(data_bin_key))
            
            # Average running time
            tmp_avg_run_time = total_time / num_images / num_points
            analysis_results[-1].avg_run_time[data_bin_key] = tmp_avg_run_time
            print("Average running time: {} s.".format(tmp_avg_run_time))

            # Average steps count
            tmp_avg_steps_count = total_steps_count // num_images // num_points
            analysis_results[-1].avg_steps_count[data_bin_key] = tmp_avg_steps_count
            print("Average steps counts: {} steps.".format(tmp_avg_steps_count))
                                         
        print("------------------------------------")
                                         
    return analysis_results

# %% [markdown]
# ### 4.1.3. Uniform cost search analysis function

# %%
def UCS_analysis(data, parameters):        
    #-------------------------------------- 4 different A* algorithms --------------------------------------
    
    def norm_UCS_list(img_array, start_node, goal_node, img_shape, theta, heuristic):
        steps_count = 0 #Save our number of steps
        visited_nodes = set() # Save our visited nodes
        frontier = [start_node] # Add the start_node to the frontier

        while len(frontier) > 0: # While there is something inside the frontier, continue the algorithm
            
            # Sort the frontier in reverse order, here Python uses timsort
            frontier = sorted(frontier, reverse = True)
            
            # Pop the last node, which has the lowest value of f
            actual_node = frontier.pop()
            
            # Add 1 to steps_count for each time we enter a node
            steps_count += 1 
            
            # Save the temporary g-score of the actual node
            tmp_g_score = actual_node.g
            
            # Return the steps_count for analysis process
            if actual_node == goal_node:
                return steps_count
            
            # Add the position (tuple(x,y)) to visited_node
            visited_nodes.add(actual_node.position)
            
            # Create a list of temporary visited nodes, add these nodes to the frontier after the for loop below 
            tmp_visited_nodes = []

            # Iterate over all neighbors of the actual node
            for next_pos in next_pos_list(img_array, actual_node, img_shape, theta):
                steps_count += 1 # Add 1 for each time we check the next node
                next_node = Node(next_pos) # Create next_node with position next_pos
                
                # If next_pos in visited_nodes, we don't do anything
                if next_pos not in visited_nodes:

                    #f = g, update f-score
                    next_node.g = tmp_g_score + 1
                    next_node.f = next_node.g
                    next_node.parent = actual_node

                    # If next_node in frontier
                    if next_node in frontier:
                        idx = frontier.index(next_node) # Find the index of next_node in the frontier
                        
                        # If the f-score of the duplicate node is more than that of the actual next_node
                        if frontier[idx] > next_node: 
                            frontier.remove(next_node) # Remove this next_node in the frontier
                            tmp_visited_nodes.append(next_node) # And append the actual next_node to the frontier
                    else:
                        tmp_visited_nodes.append(next_node) # Append the actual next_node to the frontier
            
            # Add all the nodes inside tmp_visited_nodes into frontier
            frontier += tmp_visited_nodes
        
        # Return the number of steps counted for analysis process
        return steps_count
    

    def norm_UCS_priority_queue(img_array, start_node, goal_node, img_shape, theta, heuristic):
        steps_count = 0 #Save our number of steps
        visited_nodes = set() # Save our visited nodes
        frontier = queue.PriorityQueue()
        frontier.put((0, start_node))

        while frontier.empty() == False:
            actual_node = frontier.get()[1]        
            steps_count += 1 # Add 1 for each time we enter a node
            tmp_g_score = actual_node.g

            if actual_node == goal_node:
                return steps_count

            visited_nodes.add(actual_node.position)

            # Iterate over all neighbors of the actual node
            for next_pos in next_pos_list(img_array, actual_node, img_shape, theta):
                steps_count += 1 # Add 1 for each time we check the next node
                next_node = Node(next_pos) # Create next_node with position next_pos
                
                # If next_pos in visited_nodes, we don't do anything
                if next_pos not in visited_nodes:

                    #f = g
                    next_node.g = tmp_g_score + 1
                    next_node.f = next_node.g
                    next_node.parent = actual_node

                    # Check if there exists a node having the same position as next_node (denoted as duplicate node) 
                    # in the frontier or not
                    if (next_node.f, next_node) in frontier.queue:
                        # Find the index of the duplicate node in the frontier.queue
                        idx = frontier.queue.index((next_node.f, next_node)) 

                        # Check the f-value of the 2 nodes (next_node and the duplicate node in the frontier)
                        if frontier.queue[idx][0] > next_node.f:
                            
                            # Replace the duplicate node by the next_node with lower f-score
                            # Step 1: Create a temporary queue
                            tmp_queue = queue.PriorityQueue()
                            
                            # Step 2: Put all the elements of the frontier to tmp_queue until we find the duplicate node
                            while t != frontier.queue[idx]:
                                t = frontier.get()
                                tmp_queue.put(t)
                            
                            # Step 3: Delete the duplicate node
                            t = frontier.get()
                            
                            # Step 4: Reput all the elements from the tmp_queue to the frontier
                            while tmp.empty() == False:
                                t = tmp_queue.get()
                                frontier.put(t)    
                                
                            frontier.put((next_node.f, next_node)) # Put next_node to frontier
                    else:
                        frontier.put((next_node.f, next_node)) # Put next_node to frontier
        
        # Return the number of steps counted for analysis process
        return steps_count
    
    
    def UCS_list_with_init(grid, img_array, start_node, goal_node, img_shape, theta, heuristic):    
        steps_count = 0 #Save our number of steps
        visited_nodes = set() # Save our visited nodes
        frontier = [start_node] # Add the start_node to the frontier

        while len(frontier) > 0: # While there is something inside the frontier, continue the algorithm
            
            # Sort the frontier in reverse order, here Python uses timsort
            frontier = sorted(frontier, reverse = True)
            
            # Pop the last node, which has the lowest value of f
            actual_node = frontier.pop()
            
            # Add 1 to steps_count for each time we enter a node
            steps_count += 1 
            
            # Save the temporary g-score of the actual node
            tmp_g_score = actual_node.g
            
            # Return the steps_count for analysis process
            if actual_node == goal_node:
                return steps_count
            
            # Add the position (tuple(x,y)) to visited_node
            visited_nodes.add(actual_node.position)
            
            # Create a list of temporary visited nodes, add these nodes to the frontier after the for loop below 
            tmp_visited_nodes = []

            for next_pos in grid[actual_node.position[0]][actual_node.position[1]]:
                steps_count += 1 #Add 1 for each time we check the next node
                next_node = Node(next_pos)

                if next_pos not in visited_nodes:

                    #f = g, update f-score
                    next_node.g = tmp_g_score + 1
                    next_node.f = next_node.g
                    next_node.parent = actual_node

                    # If next_node in frontier
                    if next_node in frontier:
                        idx = frontier.index(next_node) # Find the index of next_node in the frontier
                        
                        # If the f-score of the duplicate node is more than that of the actual next_node
                        if frontier[idx] > next_node: 
                            frontier.remove(next_node) # Remove this next_node in the frontier
                            tmp_visited_nodes.append(next_node) # And append the actual next_node to the frontier
                    else:
                        tmp_visited_nodes.append(next_node) # Append the actual next_node to the frontier
            
            # Add all the nodes inside tmp_visited_nodes into frontier
            frontier += tmp_visited_nodes
        
        # Return the number of steps counted for analysis process
        return steps_count
    
    
    #------------------------------------ Retrieving data from parameters ------------------------------------
    
    #List of image size:
    img_size = parameters['img_size']
    
    #Type of frontier (list or priority_queue)
    frontier_type = parameters['frontier_type']    
    
    #Type of finding neighbors (find_first_before_run or find_while_running)
    finding_neighbors = parameters['finding_neighbors']
    
    #Choose UCS version
    if finding_neighbors == 'find_while_running' and frontier_type == 'list':
        UCS = norm_UCS_list 
    elif finding_neighbors == 'find_while_running' and frontier_type == 'priority_queue':
        UCS = norm_UCS_priority_queue
    elif finding_neighbors == 'find_first_before_run' and frontier_type == 'list':
        UCS = UCS_list_with_init
    
    #Type of heuristic function (manhattan; tie_breaking_high_g_cost)
    global heuristics
    heuristic_type = parameters['heuristic_type'] 
    heuristic = heuristics[heuristic_type]
    
    #Delta for heuristic functions
    delta = 0.001
    if 'delta' in parameters.keys():
        delta = parameters['delta']

    #Number of random starting points and ending points to run analysis
    num_points = parameters['num_points'] 
    
    
    #-------------------------------------------- Analysis process --------------------------------------------
    # Store the analysis results
    analysis_results = []
    
    # Iterate over all the image size in data.keys()
    for size in data.keys():
        
        # Preparation
        analysis_results.append(AnalysisResults(size)) # Create a new AnalysisResults object and append it to the list
        pair_node_list = random_initialization(num_points, size) # Create a random pair of start node and goal node
        print("Image size: {}".format(size))

        # Run the analysis for loop
        for data_bin_key in data[size].keys():
                
            i = 1
            total_time = 0
            total_steps_count = 0
            num_images = len(data[size][data_bin_key])

            for start_node, goal_node in pair_node_list:
                
                # Create start_node and goal_node objects
                start_node = Node(start_node)
                goal_node = Node(goal_node)
                
                # Iterate over all image in data[size][data_bin_key], for example if we want to access to the list of
                # images of size 15 inside the data_bin (0,0.5) -> data[15][(0,0.5)]
                for tmp_data in data[size][data_bin_key]:
                    
                    # Different type of analysis for each finding_neighbors algorithm
                    if finding_neighbors ==  'find_first_before_run':
                        grid = make_grid(tmp_data, (size, size), 2) # Make grid of neighbors first before run the algorithm
                        start_time = time.time()
                        steps_count = UCS(grid, tmp_data, start_node, goal_node, (size, size), 2, heuristic)
                        running_time = time.time() - start_time # Running time
                    else:
                        start_time = time.time()
                        steps_count = UCS(tmp_data, start_node, goal_node, (size, size), 2, heuristic)
                        running_time = time.time() - start_time # Running time          
                    
                    total_time += running_time
                    total_steps_count += steps_count

            print("Standard deviation range: {}".format(data_bin_key))
            
            # Average running time
            tmp_avg_run_time = total_time / num_images / num_points
            analysis_results[-1].avg_run_time[data_bin_key] = tmp_avg_run_time
            print("Average running time: {} s.".format(tmp_avg_run_time))

            # Average steps count
            tmp_avg_steps_count = total_steps_count // num_images // num_points
            analysis_results[-1].avg_steps_count[data_bin_key] = tmp_avg_steps_count
            print("Average steps counts: {} steps.".format(tmp_avg_steps_count))
                                         
        print("------------------------------------")
                                         
    return analysis_results

# %% [markdown]
# ## 4.2. Analysis Results

# %% [markdown]
# ### 4.2.1. Comparison of frontier definitions
# #### 4.2.1.1. Astar
# **List (with timsort)**

# %%
parameters = {
    'img_size': img_size,
    'frontier_type': 'list',
    'finding_neighbors': 'find_while_running',
    'heuristic_type': 'manhattan', 
    'num_points': 100
}

analysis_results = Astar_analysis(data, parameters)

# Save the data
tmp_path = path + '/comparison_of_frontier_definitions'

if os.path.exists(tmp_path) == False:
    os.mkdir(tmp_path)
    
tmp_path = tmp_path + 'Astar - ' + parameters['frontier_type'] + ' - result.pkl'

with open(tmp_path, 'wb') as f:
    pickle.dump(analysis_results, f)
# Out:
# Image size: 25
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.000259091854095459 s.
# Average steps counts: 81 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.0002691388130187988 s.
# Average steps counts: 86 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.0002691006660461426 s.
# Average steps counts: 81 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.0002510666847229004 s.
# Average steps counts: 81 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.0002691197395324707 s.
# Average steps counts: 84 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.00021925687789916992 s.
# Average steps counts: 81 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.0002391982078552246 s.
# Average steps counts: 84 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.0003488397598266602 s.
# Average steps counts: 81 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0007076668739318848 s.
# Average steps counts: 174 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.0002307868003845215 s.
# Average steps counts: 81 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.0003189349174499512 s.
# Average steps counts: 81 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.0002292299270629883 s.
# Average steps counts: 81 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.00022936344146728515 s.
# Average steps counts: 81 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.00025914192199707033 s.
# Average steps counts: 81 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0005182695388793946 s.
# Average steps counts: 137 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.0002492237091064453 s.
# Average steps counts: 81 steps.
# ------------------------------------
# Image size: 50
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.001108853816986084 s.
# Average steps counts: 171 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.0009621238708496094 s.
# Average steps counts: 171 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.0008271980285644531 s.
# Average steps counts: 171 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.0009767341613769532 s.
# Average steps counts: 171 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.0008847689628601074 s.
# Average steps counts: 171 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.0008267116546630859 s.
# Average steps counts: 171 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.0008789730072021484 s.
# Average steps counts: 171 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.0009100008010864258 s.
# Average steps counts: 171 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.001456282138824463 s.
# Average steps counts: 245 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.001185152530670166 s.
# Average steps counts: 183 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.0010512089729309082 s.
# Average steps counts: 171 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.0010387444496154786 s.
# Average steps counts: 182 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.006640295982360839 s.
# Average steps counts: 1050 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.0016469478607177735 s.
# Average steps counts: 280 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0010326814651489258 s.
# Average steps counts: 171 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.001355905532836914 s.
# Average steps counts: 245 steps.
# ------------------------------------

# %% [markdown]
# **Priority queue (heapsort)**

# %%
parameters = {
    'img_size': img_size,
    'frontier_type': 'priority_queue',
    'finding_neighbors': 'find_while_running',
    'heuristic_type': 'manhattan', 
    'num_points': 100
}

analysis_results = Astar_analysis(data, parameters)

# Save the data
tmp_path = path + '/comparison_of_frontier_definitions'

if os.path.exists(tmp_path) == False:
    os.mkdir(tmp_path)
    
tmp_path = tmp_path + 'Astar - ' + parameters['frontier_type'] + ' - result.pkl'

with open(tmp_path, 'wb') as f:
    pickle.dump(analysis_results, f)
# Out:
# Image size: 25
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.0009280705451965332 s.
# Average steps counts: 298 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.0010607624053955078 s.
# Average steps counts: 294 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.0010855579376220703 s.
# Average steps counts: 298 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.0011297416687011718 s.
# Average steps counts: 300 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.0010036826133728027 s.
# Average steps counts: 281 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.0010326313972473145 s.
# Average steps counts: 298 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.001015622615814209 s.
# Average steps counts: 286 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.0009925055503845215 s.
# Average steps counts: 298 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0012267255783081055 s.
# Average steps counts: 357 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.001327180862426758 s.
# Average steps counts: 298 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.001026763916015625 s.
# Average steps counts: 298 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.0009961485862731933 s.
# Average steps counts: 298 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.0010694122314453124 s.
# Average steps counts: 298 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.000986480712890625 s.
# Average steps counts: 298 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0011063075065612792 s.
# Average steps counts: 362 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.0009641718864440918 s.
# Average steps counts: 298 steps.
# ------------------------------------
# Image size: 50
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.006265060901641846 s.
# Average steps counts: 973 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.004993376731872559 s.
# Average steps counts: 973 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.005891883373260498 s.
# Average steps counts: 973 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.00544572114944458 s.
# Average steps counts: 973 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.005404901504516601 s.
# Average steps counts: 973 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.0053379559516906734 s.
# Average steps counts: 952 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.004963507652282715 s.
# Average steps counts: 973 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.007296168804168701 s.
# Average steps counts: 973 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0055802702903747555 s.
# Average steps counts: 1031 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.004981348514556885 s.
# Average steps counts: 1003 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.005284647941589355 s.
# Average steps counts: 973 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.005208523273468018 s.
# Average steps counts: 972 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.006176977157592773 s.
# Average steps counts: 1361 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.005564088821411133 s.
# Average steps counts: 978 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.00682037353515625 s.
# Average steps counts: 973 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.0048698043823242184 s.
# Average steps counts: 950 steps.
# ------------------------------------

# %% [markdown]
# #### 4.2.1.2. GreedyBFS
# **List (with timsort)**

# %%
parameters = {
    'img_size': img_size,
    'frontier_type': 'list',
    'finding_neighbors': 'find_while_running',
    'heuristic_type': 'manhattan', 
    'num_points': 100
}

analysis_results = GreedyBFS_analysis(data, parameters)

# Save the data
tmp_path = path + '/comparison_of_frontier_definitions'

if os.path.exists(tmp_path) == False:
    os.mkdir(tmp_path)
    
tmp_path = tmp_path + 'GreedyBFS - ' + parameters['frontier_type'] + ' - result.pkl'

with open(tmp_path, 'wb') as f:
    pickle.dump(analysis_results, f)
# Out:
# Image size: 25
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.00024917364120483396 s.
# Average steps counts: 81 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.00036051750183105466 s.
# Average steps counts: 111 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.0002292513847351074 s.
# Average steps counts: 81 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.00022926807403564453 s.
# Average steps counts: 81 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.00025917768478393553 s.
# Average steps counts: 81 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.0002192234992980957 s.
# Average steps counts: 81 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.00023446321487426757 s.
# Average steps counts: 81 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.00021927356719970704 s.
# Average steps counts: 81 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.00028904438018798826 s.
# Average steps counts: 98 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.00031587600708007815 s.
# Average steps counts: 81 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.00020926475524902344 s.
# Average steps counts: 81 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.00023938655853271483 s.
# Average steps counts: 81 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.0003322720527648926 s.
# Average steps counts: 81 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.0002591276168823242 s.
# Average steps counts: 81 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0004485344886779785 s.
# Average steps counts: 124 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.0002198195457458496 s.
# Average steps counts: 81 steps.
# ------------------------------------
# Image size: 50
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.0007299399375915528 s.
# Average steps counts: 153 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.0008287549018859864 s.
# Average steps counts: 153 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.000843818187713623 s.
# Average steps counts: 153 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.000734255313873291 s.
# Average steps counts: 153 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.000682668685913086 s.
# Average steps counts: 153 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.0007176303863525391 s.
# Average steps counts: 153 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.0007076334953308106 s.
# Average steps counts: 153 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.0007206082344055175 s.
# Average steps counts: 153 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0007370686531066894 s.
# Average steps counts: 164 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.0008200955390930176 s.
# Average steps counts: 159 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.0007882642745971679 s.
# Average steps counts: 153 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.000761880874633789 s.
# Average steps counts: 153 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.0022343993186950684 s.
# Average steps counts: 404 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.0008684635162353515 s.
# Average steps counts: 167 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0007856464385986328 s.
# Average steps counts: 153 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.0009368586540222167 s.
# Average steps counts: 167 steps.
# ------------------------------------

# %% [markdown]
# **Priority queue (heapsort)**

# %%
parameters = {
    'img_size': img_size,
    'frontier_type': 'priority_queue',
    'finding_neighbors': 'find_while_running',
    'heuristic_type': 'manhattan', 
    'num_points': 100
}

analysis_results = GreedyBFS_analysis(data, parameters)

# Save the data
tmp_path = path + '/comparison_of_frontier_definitions'

if os.path.exists(tmp_path) == False:
    os.mkdir(tmp_path)
    
tmp_path = tmp_path + 'GreedyBFS - ' + parameters['frontier_type'] + ' - result.pkl'

with open(tmp_path, 'wb') as f:
    pickle.dump(analysis_results, f)
# Out:
# Image size: 25
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.00032616853713989257 s.
# Average steps counts: 85 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.00025107622146606443 s.
# Average steps counts: 85 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.0002748465538024902 s.
# Average steps counts: 85 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.0002813577651977539 s.
# Average steps counts: 85 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.00027910232543945315 s.
# Average steps counts: 85 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.00020930290222167969 s.
# Average steps counts: 85 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.00025912046432495115 s.
# Average steps counts: 85 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.00022559404373168946 s.
# Average steps counts: 85 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.00025914669036865236 s.
# Average steps counts: 108 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.0002711105346679687 s.
# Average steps counts: 85 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.0001993107795715332 s.
# Average steps counts: 85 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.00020085573196411134 s.
# Average steps counts: 85 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.0002627205848693848 s.
# Average steps counts: 85 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.0002391982078552246 s.
# Average steps counts: 85 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0002467441558837891 s.
# Average steps counts: 95 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.0002391815185546875 s.
# Average steps counts: 85 steps.
# ------------------------------------
# Image size: 50
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.00046505212783813475 s.
# Average steps counts: 155 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.0005146169662475586 s.
# Average steps counts: 155 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.0006680846214294434 s.
# Average steps counts: 155 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.0005965948104858399 s.
# Average steps counts: 155 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.0004983472824096679 s.
# Average steps counts: 155 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.0004528498649597168 s.
# Average steps counts: 155 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.00048036813735961913 s.
# Average steps counts: 155 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.00044850587844848635 s.
# Average steps counts: 155 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0004600191116333008 s.
# Average steps counts: 161 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.0004585099220275879 s.
# Average steps counts: 155 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.0004560661315917969 s.
# Average steps counts: 155 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.00044846296310424805 s.
# Average steps counts: 156 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.0015508437156677246 s.
# Average steps counts: 395 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.0006244635581970215 s.
# Average steps counts: 165 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0006293749809265137 s.
# Average steps counts: 155 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.0006673336029052734 s.
# Average steps counts: 158 steps.
# ------------------------------------

# %% [markdown]
# #### 4.2.1.3. UCS
# **List (with timsort)**

# %%
parameters = {
    'img_size': img_size,
    'frontier_type': 'list',
    'finding_neighbors': 'find_while_running',
    'heuristic_type': 'manhattan', 
    'num_points': 20 # For running faster, our value is 100
}

analysis_results = UCS_analysis(data, parameters)

# Save the data
tmp_path = path + '/comparison_of_frontier_definitions'

if os.path.exists(tmp_path) == False:
    os.mkdir(tmp_path)
    
tmp_path = tmp_path + 'UCS - ' + parameters['frontier_type'] + ' - result.pkl'

with open(tmp_path, 'wb') as f:
    pickle.dump(analysis_results, f)
# Out:
# Image size: 25
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.004980862140655518 s.
# Average steps counts: 1296 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.0040022492408752445 s.
# Average steps counts: 1289 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.004874956607818603 s.
# Average steps counts: 1296 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.004458630084991455 s.
# Average steps counts: 1295 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.004398608207702636 s.
# Average steps counts: 1285 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.004081666469573975 s.
# Average steps counts: 1296 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.004338324069976807 s.
# Average steps counts: 1291 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.003868436813354492 s.
# Average steps counts: 1296 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0036699652671813967 s.
# Average steps counts: 1233 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.004317045211791992 s.
# Average steps counts: 1296 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.004746568202972412 s.
# Average steps counts: 1296 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.004697155952453613 s.
# Average steps counts: 1296 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.004572033882141113 s.
# Average steps counts: 1296 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.0040512561798095705 s.
# Average steps counts: 1296 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.00373765230178833 s.
# Average steps counts: 1326 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.003947591781616211 s.
# Average steps counts: 1296 steps.
# ------------------------------------
# Image size: 50
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.034891831874847415 s.
# Average steps counts: 6772 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.0346603274345398 s.
# Average steps counts: 6772 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.03954635858535767 s.
# Average steps counts: 6772 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.04197862148284912 s.
# Average steps counts: 6772 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.03499726057052612 s.
# Average steps counts: 6772 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.03507082462310791 s.
# Average steps counts: 6766 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.03540605306625366 s.
# Average steps counts: 6772 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.03523311614990234 s.
# Average steps counts: 6772 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.04526561498641968 s.
# Average steps counts: 6573 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.035367584228515624 s.
# Average steps counts: 6790 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.03631831407546997 s.
# Average steps counts: 6772 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.03332061767578125 s.
# Average steps counts: 6734 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.031218457221984863 s.
# Average steps counts: 6219 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.03397048711776733 s.
# Average steps counts: 6579 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.036568629741668704 s.
# Average steps counts: 6772 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.03615834712982178 s.
# Average steps counts: 6598 steps.
# ------------------------------------

# %% [markdown]
# **Priority queue (heapsort)**

# %%
parameters = {
    'img_size': img_size,
    'frontier_type': 'priority_queue',
    'finding_neighbors': 'find_while_running',
    'heuristic_type': 'manhattan', 
    'num_points': 20 # For running faster, our value is 100
}

analysis_results = UCS_analysis(data, parameters)

# Save the data
tmp_path = path + '/comparison_of_frontier_definitions'

if os.path.exists(tmp_path) == False:
    os.mkdir(tmp_path)
    
tmp_path = tmp_path + 'UCS - ' + parameters['frontier_type'] + ' - result.pkl'

with open(tmp_path, 'wb') as f:
    pickle.dump(analysis_results, f)
# Out:
# Image size: 25
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.003338789939880371 s.
# Average steps counts: 1364 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.0031133055686950683 s.
# Average steps counts: 1356 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.0031893610954284667 s.
# Average steps counts: 1364 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.003189349174499512 s.
# Average steps counts: 1362 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.0034986495971679687 s.
# Average steps counts: 1368 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.003289163112640381 s.
# Average steps counts: 1364 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.0031415700912475588 s.
# Average steps counts: 1362 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.0030427098274230955 s.
# Average steps counts: 1364 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0033386826515197756 s.
# Average steps counts: 1390 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.0030896663665771484 s.
# Average steps counts: 1364 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.003139173984527588 s.
# Average steps counts: 1364 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.0036453604698181152 s.
# Average steps counts: 1364 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.003343355655670166 s.
# Average steps counts: 1364 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.0032239437103271486 s.
# Average steps counts: 1364 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0038841724395751952 s.
# Average steps counts: 1393 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.003970205783843994 s.
# Average steps counts: 1364 steps.
# ------------------------------------
# Image size: 50
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.03255430459976196 s.
# Average steps counts: 7108 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.02261258363723755 s.
# Average steps counts: 7108 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.02343602180480957 s.
# Average steps counts: 7108 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.02448863983154297 s.
# Average steps counts: 7108 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.022000551223754883 s.
# Average steps counts: 7108 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.02178196907043457 s.
# Average steps counts: 7117 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.021173179149627686 s.
# Average steps counts: 7108 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.022170865535736085 s.
# Average steps counts: 7108 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.021066665649414062 s.
# Average steps counts: 6870 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.02202651500701904 s.
# Average steps counts: 7081 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.022050845623016357 s.
# Average steps counts: 7108 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.020445895195007325 s.
# Average steps counts: 7065 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.01981598138809204 s.
# Average steps counts: 6408 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.02061750888824463 s.
# Average steps counts: 6836 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.021596407890319823 s.
# Average steps counts: 7108 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.02147265672683716 s.
# Average steps counts: 7090 steps.
# ------------------------------------

# %% [markdown]
# ### 4.2.2. Comparison of different algorithms and Influence of standard deviation to the running time
# #### 4.2.2.1. Astar

# %%
parameters = {
    'img_size': img_size,
    'frontier_type': 'list',
    'finding_neighbors': 'find_while_running',
    'heuristic_type': 'manhattan', 
    'num_points': 20 # For running faster, our value is 100
}

analysis_results = UCS_analysis(data, parameters)

# Save the data
tmp_path = path + '/comparison_of_different_algorithms'

if os.path.exists(tmp_path) == False:
    os.mkdir(tmp_path)
    
tmp_path = tmp_path + 'Astar - ' + parameters['frontier_type'] + ' - result.pkl'

with open(tmp_path, 'wb') as f:
    pickle.dump(analysis_results, f)
# Out:
# Image size: 25
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.0048607468605041506 s.
# Average steps counts: 1472 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.004719281196594238 s.
# Average steps counts: 1464 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.004584705829620362 s.
# Average steps counts: 1472 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.004435098171234131 s.
# Average steps counts: 1471 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.005883133411407471 s.
# Average steps counts: 1466 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.00679095983505249 s.
# Average steps counts: 1472 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.0052143454551696776 s.
# Average steps counts: 1467 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.004496240615844726 s.
# Average steps counts: 1472 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0043433189392089845 s.
# Average steps counts: 1409 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.0050090312957763675 s.
# Average steps counts: 1472 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.0049335241317749025 s.
# Average steps counts: 1472 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.005366897583007813 s.
# Average steps counts: 1472 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.0052279472351074215 s.
# Average steps counts: 1472 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.005883157253265381 s.
# Average steps counts: 1472 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.004468357563018799 s.
# Average steps counts: 1455 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.00485842227935791 s.
# Average steps counts: 1472 steps.
# ------------------------------------
# Image size: 50
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.046485626697540285 s.
# Average steps counts: 6282 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.039299631118774415 s.
# Average steps counts: 6282 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.03353309631347656 s.
# Average steps counts: 6282 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.033983373641967775 s.
# Average steps counts: 6282 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.03358427286148071 s.
# Average steps counts: 6282 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.03430478572845459 s.
# Average steps counts: 6275 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.040537893772125244 s.
# Average steps counts: 6282 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.03674706220626831 s.
# Average steps counts: 6282 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0333174467086792 s.
# Average steps counts: 6129 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.03351759910583496 s.
# Average steps counts: 6249 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.034165585041046144 s.
# Average steps counts: 6282 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.033907520771026614 s.
# Average steps counts: 6259 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.030741631984710693 s.
# Average steps counts: 5842 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.03337254524230957 s.
# Average steps counts: 6080 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.041170811653137206 s.
# Average steps counts: 6282 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.03431180715560913 s.
# Average steps counts: 6228 steps.
# ------------------------------------

# %% [markdown]
# #### 4.2.2.2. GreedyBFS

# %%
parameters = {
    'img_size': img_size,
    'frontier_type': 'list',
    'finding_neighbors': 'find_while_running',
    'heuristic_type': 'manhattan', 
    'num_points': 20 # For running faster, our value is 100
}

analysis_results = UCS_analysis(data, parameters)

# Save the data
tmp_path = path + '/comparison_of_different_algorithms'

if os.path.exists(tmp_path) == False:
    os.mkdir(tmp_path)
    
tmp_path = tmp_path + 'GreedyBFS - ' + parameters['frontier_type'] + ' - result.pkl'

with open(tmp_path, 'wb') as f:
    pickle.dump(analysis_results, f)
# Out:
# Image size: 25
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.0063545823097229 s.
# Average steps counts: 1999 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.006225025653839112 s.
# Average steps counts: 1984 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.00568917989730835 s.
# Average steps counts: 1999 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.005720913410186768 s.
# Average steps counts: 1998 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.005837440490722656 s.
# Average steps counts: 1993 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.006758129596710205 s.
# Average steps counts: 1999 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.0057306051254272464 s.
# Average steps counts: 1987 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.006741797924041748 s.
# Average steps counts: 1999 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0061928749084472655 s.
# Average steps counts: 1870 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.006663382053375244 s.
# Average steps counts: 1999 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.006950640678405761 s.
# Average steps counts: 1999 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.006339013576507568 s.
# Average steps counts: 1999 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.006243741512298584 s.
# Average steps counts: 1999 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.006619977951049805 s.
# Average steps counts: 1999 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.006361162662506104 s.
# Average steps counts: 1920 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.006179869174957275 s.
# Average steps counts: 1999 steps.
# ------------------------------------
# Image size: 50
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.0449946403503418 s.
# Average steps counts: 8627 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.04702217578887939 s.
# Average steps counts: 8627 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.05046912431716919 s.
# Average steps counts: 8627 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.04382257461547852 s.
# Average steps counts: 8627 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.043470776081085204 s.
# Average steps counts: 8627 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.043798184394836424 s.
# Average steps counts: 8616 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.054995954036712646 s.
# Average steps counts: 8627 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.04453829526901245 s.
# Average steps counts: 8627 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.04460667371749878 s.
# Average steps counts: 8396 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.06206554174423218 s.
# Average steps counts: 8607 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.06402784585952759 s.
# Average steps counts: 8627 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.0748320460319519 s.
# Average steps counts: 8585 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.04417251348495484 s.
# Average steps counts: 8070 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.04387127161026001 s.
# Average steps counts: 8316 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.04718579053878784 s.
# Average steps counts: 8627 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.045889079570770264 s.
# Average steps counts: 8460 steps.
# ------------------------------------

# %% [markdown]
# #### 4.2.2.3. UCS

# %%
parameters = {
    'img_size': img_size,
    'frontier_type': 'list',
    'finding_neighbors': 'find_while_running',
    'heuristic_type': 'manhattan', 
    'num_points': 20 # For running faster, our value is 100
}

analysis_results = UCS_analysis(data, parameters)

# Save the data
tmp_path = path + '/comparison_of_different_algorithms'

if os.path.exists(tmp_path) == False:
    os.mkdir(tmp_path)
    
tmp_path = tmp_path + 'UCS - ' + parameters['frontier_type'] + ' - result.pkl'

with open(tmp_path, 'wb') as f:
    pickle.dump(analysis_results, f)
# Out:
# Image size: 25
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.00556333065032959 s.
# Average steps counts: 1601 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.005051517486572265 s.
# Average steps counts: 1604 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.00589137077331543 s.
# Average steps counts: 1601 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.00504457950592041 s.
# Average steps counts: 1600 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.004983663558959961 s.
# Average steps counts: 1597 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.004786348342895508 s.
# Average steps counts: 1601 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.00476222038269043 s.
# Average steps counts: 1595 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.004610240459442139 s.
# Average steps counts: 1601 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.00472416877746582 s.
# Average steps counts: 1520 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.005171644687652588 s.
# Average steps counts: 1601 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.00560145378112793 s.
# Average steps counts: 1601 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.005600094795227051 s.
# Average steps counts: 1601 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.004600203037261963 s.
# Average steps counts: 1601 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.004912233352661133 s.
# Average steps counts: 1601 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.004434907436370849 s.
# Average steps counts: 1555 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.004912853240966797 s.
# Average steps counts: 1601 steps.
# ------------------------------------
# Image size: 50
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.031279253959655764 s.
# Average steps counts: 5770 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.03572777509689331 s.
# Average steps counts: 5770 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.03535493612289429 s.
# Average steps counts: 5770 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.03114677667617798 s.
# Average steps counts: 5770 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.03252155780792236 s.
# Average steps counts: 5770 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.03207322359085083 s.
# Average steps counts: 5772 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.04150620698928833 s.
# Average steps counts: 5770 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.030952036380767822 s.
# Average steps counts: 5770 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.02854386568069458 s.
# Average steps counts: 5582 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.030776596069335936 s.
# Average steps counts: 5753 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.03091639280319214 s.
# Average steps counts: 5770 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.030821692943573 s.
# Average steps counts: 5730 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.0340078592300415 s.
# Average steps counts: 5312 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.031209993362426757 s.
# Average steps counts: 5539 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.03003154993057251 s.
# Average steps counts: 5770 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.029810452461242677 s.
# Average steps counts: 5680 steps.
# ------------------------------------

# %% [markdown]
# ### 4.2.3. Heuristic functions
# #### 4.2.3.1. Tie-breaking High g-cost

# %%
# img_size = [img_size[1], img_size[4]] # Only image size 25 and 50 for the original img_size = [15,20,25,30,50,75,100]

parameters = {
    'img_size': img_size,
    'frontier_type': 'list',
    'finding_neighbors': 'find_while_running',
    'heuristic_type': 'manhattan', 
    'num_points': 100,
    'delta': 0.01 # Change delta here
}

analysis_results = Astar_analysis(data, parameters) # Use only Astar

# Save the data
tmp_path = path + '/heuristic_functions'

if os.path.exists(tmp_path) == False:
    os.mkdir(tmp_path)
    
tmp_path = tmp_path + 'tie-breaking-high-g-cost - ' + ' delta = ' + str(parameters['delta']) + ' - result.pkl'

with open(tmp_path, 'wb') as f:
    pickle.dump(analysis_results, f)
# Out:
# Image size: 25
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.00026020288467407224 s.
# Average steps counts: 79 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.00024692535400390627 s.
# Average steps counts: 80 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.00023920059204101562 s.
# Average steps counts: 79 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.0002292323112487793 s.
# Average steps counts: 80 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.0002391982078552246 s.
# Average steps counts: 82 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.00022923707962036133 s.
# Average steps counts: 79 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.0002690982818603516 s.
# Average steps counts: 80 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.0002791070938110352 s.
# Average steps counts: 79 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.00034025192260742185 s.
# Average steps counts: 107 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.0002984023094177246 s.
# Average steps counts: 79 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.0002297043800354004 s.
# Average steps counts: 79 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.00024399995803833007 s.
# Average steps counts: 79 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.00024916887283325193 s.
# Average steps counts: 79 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.0002192521095275879 s.
# Average steps counts: 79 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0005650496482849121 s.
# Average steps counts: 152 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.00028051376342773436 s.
# Average steps counts: 79 steps.
# ------------------------------------
# Image size: 50
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.0010274600982666015 s.
# Average steps counts: 167 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.0009993886947631835 s.
# Average steps counts: 167 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.0008590388298034668 s.
# Average steps counts: 167 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.0009598875045776367 s.
# Average steps counts: 167 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.0009192681312561035 s.
# Average steps counts: 167 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.0008355498313903809 s.
# Average steps counts: 167 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.0009263372421264649 s.
# Average steps counts: 167 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.0008478808403015137 s.
# Average steps counts: 167 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0013185834884643555 s.
# Average steps counts: 230 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.0009370231628417968 s.
# Average steps counts: 169 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.0008575892448425292 s.
# Average steps counts: 167 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.0010950207710266114 s.
# Average steps counts: 172 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.003766193389892578 s.
# Average steps counts: 637 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.0021149277687072753 s.
# Average steps counts: 324 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0010102176666259765 s.
# Average steps counts: 167 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.0015679430961608887 s.
# Average steps counts: 239 steps.
# ------------------------------------

# %% [markdown]
# #### 4.2.3.2. Variance of Tie-breaking High g-cost

# %%
# img_size = [img_size[1], img_size[4]] # Only image size 25 and 50 for the original img_size = [15,20,25,30,50,75,100]

parameters = {
    'img_size': img_size,
    'frontier_type': 'list',
    'finding_neighbors': 'find_while_running',
    'heuristic_type': 'manhattan', 
    'num_points': 100,
    'delta': 0.01 # Change delta here
}

analysis_results = Astar_analysis(data, parameters) # Use only Astar

# Save the data
tmp_path = path + '/heuristic_functions'

if os.path.exists(tmp_path) == False:
    os.mkdir(tmp_path)
    
tmp_path = tmp_path + 'variance-of-tie-breaking-high-g-cost - ' + ' delta = ' + str(parameters['delta']) + ' - result.pkl'

with open(tmp_path, 'wb') as f:
    pickle.dump(analysis_results, f)
# Out:
# Image size: 25
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.0002863764762878418 s.
# Average steps counts: 84 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.00028319597244262694 s.
# Average steps counts: 87 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.00027479171752929686 s.
# Average steps counts: 84 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.0003387904167175293 s.
# Average steps counts: 84 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.0003845691680908203 s.
# Average steps counts: 86 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.0002571034431457519 s.
# Average steps counts: 84 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.00035547494888305665 s.
# Average steps counts: 85 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.00029889345169067385 s.
# Average steps counts: 84 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0007056212425231934 s.
# Average steps counts: 177 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.0002867579460144043 s.
# Average steps counts: 84 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.00031400442123413085 s.
# Average steps counts: 84 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.0003084111213684082 s.
# Average steps counts: 84 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.00027906179428100587 s.
# Average steps counts: 84 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.000281672477722168 s.
# Average steps counts: 84 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0006563520431518555 s.
# Average steps counts: 149 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.0004121994972229004 s.
# Average steps counts: 84 steps.
# ------------------------------------
# Image size: 50
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.0011150574684143067 s.
# Average steps counts: 148 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.0009165620803833008 s.
# Average steps counts: 148 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.0010262537002563477 s.
# Average steps counts: 148 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.0007225131988525391 s.
# Average steps counts: 148 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.0008156704902648926 s.
# Average steps counts: 148 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.0007512688636779786 s.
# Average steps counts: 149 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.0007076334953308106 s.
# Average steps counts: 148 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.0007022309303283691 s.
# Average steps counts: 148 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.001155257225036621 s.
# Average steps counts: 209 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.0008146023750305176 s.
# Average steps counts: 149 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.0007726883888244629 s.
# Average steps counts: 148 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.0010686612129211426 s.
# Average steps counts: 178 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.0020355606079101563 s.
# Average steps counts: 331 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.001433725357055664 s.
# Average steps counts: 265 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0006877303123474122 s.
# Average steps counts: 148 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.0010630011558532715 s.
# Average steps counts: 203 steps.
# ------------------------------------

# %% [markdown]
# #### 4.2.3.3. Tie-breaking Low g-cost

# %%
# img_size = [img_size[1], img_size[4]] # Only image size 25 and 50 for the original img_size = [15,20,25,30,50,75,100]

parameters = {
    'img_size': img_size,
    'frontier_type': 'list',
    'finding_neighbors': 'find_while_running',
    'heuristic_type': 'manhattan', 
    'num_points': 100,
    'delta': 0.01 # Change delta here
}

analysis_results = Astar_analysis(data, parameters) # Use only Astar

# Save the data
tmp_path = path + '/heuristic_functions'

if os.path.exists(tmp_path) == False:
    os.mkdir(tmp_path)
    
tmp_path = tmp_path + 'tie-breaking-low-g-cost - ' + ' delta = ' + str(parameters['delta']) + ' - result.pkl'

with open(tmp_path, 'wb') as f:
    pickle.dump(analysis_results, f)
# Out:
# Image size: 25
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.00026709556579589843 s.
# Average steps counts: 83 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.00028906583786010744 s.
# Average steps counts: 82 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.0002890181541442871 s.
# Average steps counts: 83 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.0002591347694396973 s.
# Average steps counts: 83 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.00026862382888793947 s.
# Average steps counts: 84 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.0002691054344177246 s.
# Average steps counts: 83 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.00028898000717163084 s.
# Average steps counts: 86 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.0002491593360900879 s.
# Average steps counts: 83 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.00039652109146118167 s.
# Average steps counts: 122 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.00025912284851074217 s.
# Average steps counts: 83 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.00024911403656005857 s.
# Average steps counts: 83 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.00025914430618286134 s.
# Average steps counts: 83 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.00026422739028930664 s.
# Average steps counts: 83 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.00026123046875 s.
# Average steps counts: 83 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0008278703689575196 s.
# Average steps counts: 183 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.00025856971740722656 s.
# Average steps counts: 83 steps.
# ------------------------------------
# Image size: 50
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.0008527541160583496 s.
# Average steps counts: 170 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.000847170352935791 s.
# Average steps counts: 170 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.000829920768737793 s.
# Average steps counts: 170 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.0008623838424682617 s.
# Average steps counts: 170 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.0009335851669311523 s.
# Average steps counts: 170 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.0009610223770141602 s.
# Average steps counts: 170 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.0009822750091552734 s.
# Average steps counts: 170 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.0008608889579772949 s.
# Average steps counts: 170 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0014887070655822754 s.
# Average steps counts: 254 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.0011969494819641113 s.
# Average steps counts: 172 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.0011435675621032715 s.
# Average steps counts: 170 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.001047670841217041 s.
# Average steps counts: 172 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.002631216049194336 s.
# Average steps counts: 436 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.0023743844032287596 s.
# Average steps counts: 355 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.000926511287689209 s.
# Average steps counts: 170 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.00107774019241333 s.
# Average steps counts: 198 steps.
# ------------------------------------

# %% [markdown]
# #### 4.2.3.4. Variance of Tie-breaking Low g-cost

# %%
# img_size = [img_size[1], img_size[4]] # Only image size 25 and 50 for the original img_size = [15,20,25,30,50,75,100]

parameters = {
    'img_size': img_size,
    'frontier_type': 'list',
    'finding_neighbors': 'find_while_running',
    'heuristic_type': 'manhattan', 
    'num_points': 100,
    'delta': 0.01 # Change delta here
}

analysis_results = Astar_analysis(data, parameters) # Use only Astar

# Save the data
tmp_path = path + '/heuristic_functions'

if os.path.exists(tmp_path) == False:
    os.mkdir(tmp_path)
    
tmp_path = tmp_path + 'variance-of-tie-breaking-low-g-cost - ' + ' delta = ' + str(parameters['delta']) + ' - result.pkl'

with open(tmp_path, 'wb') as f:
    pickle.dump(analysis_results, f)
# Out:
# Image size: 25
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.0002292013168334961 s.
# Average steps counts: 76 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.00031896591186523436 s.
# Average steps counts: 110 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.00021924257278442384 s.
# Average steps counts: 76 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.00023923635482788085 s.
# Average steps counts: 76 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.00023169755935668944 s.
# Average steps counts: 77 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.00022916793823242189 s.
# Average steps counts: 76 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.00022919416427612303 s.
# Average steps counts: 78 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.00027008056640625 s.
# Average steps counts: 76 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0005058836936950683 s.
# Average steps counts: 141 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.0002859139442443848 s.
# Average steps counts: 76 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.00023900985717773438 s.
# Average steps counts: 76 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.0002510690689086914 s.
# Average steps counts: 76 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.0003180503845214844 s.
# Average steps counts: 76 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.00027142763137817384 s.
# Average steps counts: 76 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0003803205490112305 s.
# Average steps counts: 111 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.00027149438858032227 s.
# Average steps counts: 76 steps.
# ------------------------------------
# Image size: 50
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.0008687925338745117 s.
# Average steps counts: 171 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.000868062973022461 s.
# Average steps counts: 171 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.0009212708473205567 s.
# Average steps counts: 171 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.000935070514678955 s.
# Average steps counts: 171 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.0008731341361999512 s.
# Average steps counts: 171 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.0009237694740295411 s.
# Average steps counts: 174 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.0008646368980407715 s.
# Average steps counts: 171 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.0008431315422058105 s.
# Average steps counts: 171 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0011561036109924317 s.
# Average steps counts: 223 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.0009343743324279786 s.
# Average steps counts: 176 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.0009336495399475098 s.
# Average steps counts: 171 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.001043689250946045 s.
# Average steps counts: 185 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.003566884994506836 s.
# Average steps counts: 579 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.0013658618927001953 s.
# Average steps counts: 258 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0009232354164123535 s.
# Average steps counts: 171 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.002107386589050293 s.
# Average steps counts: 283 steps.
# ------------------------------------

# %% [markdown]
# ### 4.2.4. Find neighbors

# %% [markdown]
# **Find while running**

# %%
# img_size = [img_size[1], img_size[4]] # Only image size 25 and 50 for the original img_size = [15,20,25,30,50,75,100]

parameters = {
    'img_size': img_size,
    'frontier_type': 'list',
    'finding_neighbors': 'find_while_running',
    'heuristic_type': 'manhattan', 
    'num_points': 100,
}

analysis_results = Astar_analysis(data, parameters) # Use only Astar

# Save the data
tmp_path = path + '/heuristic_functions'

if os.path.exists(tmp_path) == False:
    os.mkdir(tmp_path)
    
tmp_path = tmp_path + 'find_while_running - result.pkl'

with open(tmp_path, 'wb') as f:
    pickle.dump(analysis_results, f)
# Out:
# Image size: 25
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.00028322458267211916 s.
# Average steps counts: 86 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.0002755117416381836 s.
# Average steps counts: 89 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.00025908231735229494 s.
# Average steps counts: 86 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.0002643418312072754 s.
# Average steps counts: 86 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.0003130936622619629 s.
# Average steps counts: 88 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.0004146265983581543 s.
# Average steps counts: 86 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.0003580164909362793 s.
# Average steps counts: 89 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.00026108503341674803 s.
# Average steps counts: 86 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0004699444770812988 s.
# Average steps counts: 143 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.00024912118911743166 s.
# Average steps counts: 86 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.00024022579193115235 s.
# Average steps counts: 86 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.00025457143783569336 s.
# Average steps counts: 86 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.00025918483734130857 s.
# Average steps counts: 86 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.0002592134475708008 s.
# Average steps counts: 86 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.00045608997344970704 s.
# Average steps counts: 126 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.00027374267578125 s.
# Average steps counts: 86 steps.
# ------------------------------------
# Image size: 50
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.0011044025421142578 s.
# Average steps counts: 170 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.001530451774597168 s.
# Average steps counts: 170 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.0010220623016357422 s.
# Average steps counts: 170 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.0009763264656066895 s.
# Average steps counts: 170 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.0008724641799926758 s.
# Average steps counts: 170 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.0009728360176086426 s.
# Average steps counts: 174 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.001029500961303711 s.
# Average steps counts: 170 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.0012563633918762206 s.
# Average steps counts: 170 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0014485812187194824 s.
# Average steps counts: 254 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.001274704933166504 s.
# Average steps counts: 199 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.0009693336486816406 s.
# Average steps counts: 170 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.0009630441665649414 s.
# Average steps counts: 170 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.0028839206695556643 s.
# Average steps counts: 494 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.0014720869064331055 s.
# Average steps counts: 262 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0009084010124206543 s.
# Average steps counts: 170 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.0012075591087341308 s.
# Average steps counts: 209 steps.
# ------------------------------------

# %% [markdown]
# **Find first before run**

# %%
# img_size = [img_size[1], img_size[4]] # Only image size 25 and 50 for the original img_size = [15,20,25,30,50,75,100]

parameters = {
    'img_size': img_size,
    'frontier_type': 'list',
    'finding_neighbors': 'find_first_before_run',
    'heuristic_type': 'manhattan', 
    'num_points': 100,
}

analysis_results = Astar_analysis(data, parameters) # Use only Astar

# Save the data
tmp_path = path + '/find_neighbors'

if os.path.exists(tmp_path) == False:
    os.mkdir(tmp_path)
    
tmp_path = tmp_path + 'find_first_before_run - result.pkl'

with open(tmp_path, 'wb') as f:
    pickle.dump(analysis_results, f)
# Out:
# Image size: 25
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.00025854825973510744 s.
# Average steps counts: 85 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.0003008317947387695 s.
# Average steps counts: 87 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.00028045415878295897 s.
# Average steps counts: 85 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.00028954267501831056 s.
# Average steps counts: 85 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.00030640363693237307 s.
# Average steps counts: 87 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.000331573486328125 s.
# Average steps counts: 85 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.0002793335914611816 s.
# Average steps counts: 87 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.00028368711471557615 s.
# Average steps counts: 85 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0003969526290893555 s.
# Average steps counts: 127 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.00025932788848876954 s.
# Average steps counts: 85 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.00023885488510131837 s.
# Average steps counts: 85 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.000310060977935791 s.
# Average steps counts: 85 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.00030918359756469725 s.
# Average steps counts: 85 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.00023924827575683594 s.
# Average steps counts: 85 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0004488253593444824 s.
# Average steps counts: 126 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.00021918773651123048 s.
# Average steps counts: 85 steps.
# ------------------------------------
# Image size: 50
# Standard deviation range: (0.0, 0.5)
# Average running time: 0.000849761962890625 s.
# Average steps counts: 166 steps.
# Standard deviation range: (0.5, 1.0)
# Average running time: 0.0008372282981872559 s.
# Average steps counts: 166 steps.
# Standard deviation range: (1.0, 1.5)
# Average running time: 0.0007908749580383301 s.
# Average steps counts: 166 steps.
# Standard deviation range: (1.5, 2.0)
# Average running time: 0.0009044957160949707 s.
# Average steps counts: 166 steps.
# Standard deviation range: (2.0, 2.5)
# Average running time: 0.0007886552810668946 s.
# Average steps counts: 166 steps.
# Standard deviation range: (2.5, 3.0)
# Average running time: 0.0008015179634094238 s.
# Average steps counts: 167 steps.
# Standard deviation range: (3.0, 3.5)
# Average running time: 0.0007840824127197265 s.
# Average steps counts: 166 steps.
# Standard deviation range: (3.5, 4.0)
# Average running time: 0.0008074212074279786 s.
# Average steps counts: 166 steps.
# Standard deviation range: (4.0, 4.5)
# Average running time: 0.0011643004417419434 s.
# Average steps counts: 243 steps.
# Standard deviation range: (4.5, 5.0)
# Average running time: 0.0008279824256896973 s.
# Average steps counts: 169 steps.
# Standard deviation range: (5.0, 5.5)
# Average running time: 0.000848078727722168 s.
# Average steps counts: 166 steps.
# Standard deviation range: (5.5, 6.0)
# Average running time: 0.0009179520606994629 s.
# Average steps counts: 177 steps.
# Standard deviation range: (6.0, 6.5)
# Average running time: 0.0032025957107543945 s.
# Average steps counts: 569 steps.
# Standard deviation range: (6.5, 7.0)
# Average running time: 0.002673957347869873 s.
# Average steps counts: 384 steps.
# Standard deviation range: (7.0, 7.5)
# Average running time: 0.0007677245140075684 s.
# Average steps counts: 166 steps.
# Standard deviation range: (7.5, 8.0)
# Average running time: 0.0010955333709716797 s.
# Average steps counts: 214 steps.
# ------------------------------------

# %% [markdown]
# # 5. Path visualization

# %%
from PIL import Image # work with images
import numpy as np
import queue
import os 
import pygame
import time

file_name = "Mars_MGS_MOLA_DEM.jpg" #The name of the file we want to save
img = Image.open(file_name) #Open our saved file above
img = img.convert("L") #Convert to one channel grey image
img_array = np.asarray(img)  #Convert the image to an array
img_array = img_array.astype('int32')
img = img_array[3000:3050,3000:3050].astype('float64')

WHITE = (255, 255, 255)
PURPLE = (128, 0, 128)
GREY = (128, 128, 128)
TURQUOISE = (64, 224, 208)
RED = (255, 0, 0)
GREEN = (0, 255, 0)
YELLOW = (255, 255, 0)

class Node:
        length = len(img)
        def __init__(self, row, col, width):
                self.row = row
                self.col = col
                self.x = row * width
                self.y = col * width
                self.color = WHITE
                self.neighbors = []
                self.width = width
                self.height = img[col][row]
                self.g = float('inf')
                self.f = float('inf')
                self.parent = None
                
        def get_position(self):
                return self.row, self.col
        
        def is_neighbor(self,other,gradient):
               return abs(self.height - other.height) <= gradient 
        
        def get_neighbors(self, grid,gradient):
                if self.row < Node.length - 1 and self.is_neighbor(grid[self.row + 1][self.col],gradient):
                        self.neighbors.append(grid[self.row + 1][self.col])

                if self.row > 0 and self.is_neighbor(grid[self.row - 1][self.col],gradient):
                        self.neighbors.append(grid[self.row - 1][self.col])

                if self.col < Node.length - 1 and self.is_neighbor(grid[self.row][self.col + 1],gradient): 
                        self.neighbors.append(grid[self.row][self.col + 1])

                if self.col > 0 and self.is_neighbor(grid[self.row][self.col - 1],gradient): 
                        self.neighbors.append(grid[self.row][self.col - 1])

        def draw(self, screen):
                pygame.draw.rect(screen, self.color, (self.x, self.y, self.width, self.width))
                

# Manhattan distance
def manhattan(node ,goal):
    x_node, y_node = node.get_position()
    x_goal, y_goal = goal.get_position()
    return abs(x_node - x_goal) + abs(y_node - y_goal)

# There are many states with the same f-cost, and we have to choose the order in which to expand them. 
# For tie_breaking_high_g_cost, we preferred states closer to the goal node than the goal state.
def tie_breaking_high_g_cost(node, goal, delta = 0.1):
    x_node, y_node = node.get_position()
    x_goal, y_goal = goal.get_position()
    return manhattan(node, goal) * (1 + delta)

# There are many states with the same f-cost, and we have to choose the order in which to expand them. 
# For tie_breaking_low_g_cost, we preferred states closer to the start node than the goal state.
def tie_breaking_low_g_cost(node, goal, delta = 0.1):
    x_node, y_node = node.get_position()
    x_goal, y_goal = goal.get_position()
    return manhattan(node, goal) * (1 - delta)


    
def draw_file_name(current, draw):
        while current.parent != None:
                current = current.parent
                current.color = PURPLE
                draw()
        return None

def make_grid(rows, width):
        grid = []
        space = width // rows
        for i in range(rows):
                grid.append([])
                for j in range(rows):
                        node = Node(i, j, space)
                        grid[i].append(node)
        return grid


def draw_grid(screen, rows, width):
        space = width // rows
        for i in range(rows):
                pygame.draw.line(screen, GREY, (0, i * space), (width, i * space))
                for j in range(rows):
                        pygame.draw.line(screen, GREY, (j * space, 0), (j * space, width))


def draw_main(screen, grid, rows, width):
        screen.fill(WHITE)
        for row in grid:
                for node in row:
                        node.draw(screen)
        draw_grid(screen, rows, width)
        pygame.display.update()

def Astar(draw, grid, start, goal, heuristic):
        step = 0
        open_set = queue.PriorityQueue()
        open_set.put((0, step, start))
        start.g = 0
        check = {start}
        while not open_set.empty():
                step += 1
                current = open_set.get()[2]
                check.remove(current)
                if current.get_position() == goal.get_position():
                        draw_file_name(goal, draw)
                        goal.color = TURQUOISE
                        return True, step
                for neighbor in current.neighbors:
                        step += 1
                        tmp = current.g + 1
                        if tmp < neighbor.g:
                                neighbor.parent = current
                                neighbor.g = tmp
                                neighbor.f = tmp + heuristic(neighbor, goal)
                                if neighbor not in check:
                                        open_set.put((neighbor.f, step, neighbor))
                                        check.add(neighbor)
                                        neighbor.color = GREEN
                draw()
                if current != start:
                        current.color = RED
        return False

def GreedyBFS(draw, grid, start, goal, heuristic):
        step = 0
        open_set = queue.PriorityQueue()
        open_set.put((0, step, start))
        start.g = 0
        check = {start}
        while not open_set.empty():
                step += 1
                current = open_set.get()[2]
                check.remove(current)
                if current.get_position() == goal.get_position():
                        draw_file_name(goal, draw)
                        goal.color = TURQUOISE
                        return True
                for neighbor in current.neighbors:
                        step += 1
                        tmp = current.g + 1
                        if tmp < neighbor.g:
                                neighbor.parent = current
                                neighbor.g = tmp
                                neighbor.f = heuristic(neighbor, goal)
                                if neighbor not in check:
                                        open_set.put((neighbor.f, step, neighbor))
                                        check.add(neighbor)
                                        neighbor.color = GREEN
                draw()
                if current != start:
                        current.color = RED
        return False
    
def UCS(draw, grid, start, goal, heuristic = None):
        step = 0
        open_set = queue.PriorityQueue()
        open_set.put((0, step, start))
        start.g = 0
        check = {start}
        while not open_set.empty():
                step += 1
                current = open_set.get()[2]
                check.remove(current)
                if current.get_position() == goal.get_position():
                        draw_file_name(goal, draw)
                        goal.color = TURQUOISE
                        return True
                for neighbor in current.neighbors:
                        step += 1
                        tmp = current.g + 1
                        if tmp < neighbor.g:
                                neighbor.parent = current
                                neighbor.g = tmp
                                neighbor.f = tmp
                                if neighbor not in check:
                                        open_set.put((neighbor.f, step, neighbor))
                                        check.add(neighbor)
                                        neighbor.color = GREEN
                draw()
                if current != start:
                        current.color = RED
        return False
    
def main(screen, width, start, goal, gradient, algorithm, heuristic = manhattan):
        n = len(img)
        grid = make_grid(n, width)
        x_start,y_start = start
        x_goal,y_goal = goal
        run = True
        while run:
                draw_main(screen, grid, n, width)
                start = grid[y_start][x_start]
                start.color = YELLOW
                goal = grid[y_goal][x_goal]
                goal.color = TURQUOISE
                for row in grid:
                    for node in row:
                        node.get_neighbors(grid,gradient)
                result = algorithm(lambda: draw_main(screen, grid, n, width), grid, start, goal, heuristic)
                if result == True:
                    time.sleep(3)
                    run = False
        pygame.quit()
        
start = (1,0)
goal = (49,49)
gradient = 1 # Take 1 for see the big difference between heuristic functions for low version of Astar
# Out:
# pygame 2.1.1 (SDL 2.0.18, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## 5.1. Astar

# %%
WIDTH = 200

screen = pygame.display.set_mode((WIDTH, WIDTH))
pygame.event.get()
pygame.display.set_caption("Manhattan distance - low version of Astar")
main(screen, WIDTH,start,goal,gradient,Astar,manhattan)

# %%
pygame.event.get()
screen = pygame.display.set_mode((WIDTH, WIDTH))
pygame.display.set_caption("Tie-breaking High g-cost - low version of Astar")
main(screen, WIDTH,start,goal,gradient,Astar,tie_breaking_high_g_cost)

# %%
screen = pygame.display.set_mode((WIDTH, WIDTH))
pygame.display.set_caption("Tie-breaking Low g-cost - low version of Astar")

main(screen, WIDTH,start,goal,gradient,Astar,tie_breaking_low_g_cost)

# %% [markdown]
# ## 5.2. Greedy BFS

# %%
screen = pygame.display.set_mode((WIDTH, WIDTH))
pygame.display.set_caption("GreedyBFS")

main(screen, WIDTH,start,goal,gradient,GreedyBFS)

# %% [markdown]
# ## 5.3. UCS

# %%
screen = pygame.display.set_mode((WIDTH, WIDTH))
pygame.display.set_caption("UCS")

main(screen, WIDTH,start,goal,gradient,UCS,manhattan)
